# %%
import autopager
import requests

# %%
from selenium import webdriver

# %%
from selenium.webdriver.chrome.options import Options

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://forums.oneplus.com/threads/marsh-cm13.405700/')
print(driver.title)
# Out:
# ROM - Marsh [CM13] - OnePlus Community

# %%
html = driver.page_source
button_urls = autopager.urls(html)
print(button_urls)
# Out:
# ['threads/marsh-cm13.405700/', 'threads/marsh-cm13.405700/page-2', 'threads/marsh-cm13.405700/page-3', 'threads/marsh-cm13.405700/page-4', 'threads/marsh-cm13.405700/page-5', 'threads/marsh-cm13.405700/page-6', 'threads/marsh-cm13.405700/page-349', 'threads/marsh-cm13.405700/page-2', 'threads/marsh-cm13.405700/', 'threads/marsh-cm13.405700/page-2', 'threads/marsh-cm13.405700/page-3', 'threads/marsh-cm13.405700/page-4', 'threads/marsh-cm13.405700/page-5', 'threads/marsh-cm13.405700/page-6', 'threads/marsh-cm13.405700/page-349', 'threads/marsh-cm13.405700/page-2']

# %%
button_urls
# Out:
# ['threads/marsh-cm13.405700/',
#  'threads/marsh-cm13.405700/page-2',
#  'threads/marsh-cm13.405700/page-3',
#  'threads/marsh-cm13.405700/page-4',
#  'threads/marsh-cm13.405700/page-5',
#  'threads/marsh-cm13.405700/page-6',
#  'threads/marsh-cm13.405700/page-349',
#  'threads/marsh-cm13.405700/page-2',
#  'threads/marsh-cm13.405700/',
#  'threads/marsh-cm13.405700/page-2',
#  'threads/marsh-cm13.405700/page-3',
#  'threads/marsh-cm13.405700/page-4',
#  'threads/marsh-cm13.405700/page-5',
#  'threads/marsh-cm13.405700/page-6',
#  'threads/marsh-cm13.405700/page-349',
#  'threads/marsh-cm13.405700/page-2']

# %%
autopager.select(html)
# Out:
# [<Selector xpath='.//a[@href]' data='<a href="https://myaccount.books.com....'>,
#  <Selector xpath='.//a[@href]' data='<a href="https://myaccount.books.com....'>,
#  <Selector xpath='.//a[@href]' data='<a href="https://myaccount.books.com....'>,
#  <Selector xpath='.//a[@href]' data='<a href="https://myaccount.books.com....'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
#  <Selector xpath='.//a[@href]' data='<a rel="change_page" href="//search.b...'>,
# ...

# %%
html
# Out:
# '<html class="" lang="en" data-whatinput="initial" data-whatintent="initial"><head><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="user-scalable=no, width=device-width, initial-scale=1.0, maximum-scale=1.0">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black-translucent">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n    <meta name="apple-touch-fullscreen" content="no">\n    \n        <meta name="description" content="Shop the best selection of Folk &amp; Traditional Instruments at Music &amp; Arts.">\n        <title>Folk &amp; Traditio
# ...

# %%
next_page_text_example = "javascript:__doPostBack('WebPager1','2')"

# %%
for next_page_text in button_urls:
    text = driver.find_element_by_xpath('//a[@href="'+next_page_text+'"]').text
    print(text)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
driver.close()
